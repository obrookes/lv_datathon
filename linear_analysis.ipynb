# %%
import pandas as pd

# %%
data = pd.read_csv('new_train.csv')

# %%
data
# Out:
#      Customer Country State Code     State Response  Coverage Education  \
# 0     BU79786      US         KS    Kansas       No     Basic  Bachelor
# 1     QZ44356      US         NE  Nebraska       No  Extended  Bachelor
# 2     AI49188      US         OK  Oklahoma       No   Premium  Bachelor
# 3     WW63253      US         MO  Missouri       No     Basic  Bachelor
# 4     HB64268      US         KS    Kansas       No     Basic  Bachelor
# ...       ...     ...        ...       ...      ...       ...       ...
# 7779  FV33188      US         KS    Kansas      Yes     Basic  Bachelor
# 7780  ZQ94561      US         KS    Kansas       No     Basic   College
# 7781  JZ16164      US         IA      Iowa       No  Extended  Bachelor
# 7782  MU63232      US         NE  Nebraska       No  Extended    Master
# 7783  CG13512      US         IA      Iowa       No     Basic   College
#
#      Effective To Date EmploymentStatus Gender  ...  \
# ...
